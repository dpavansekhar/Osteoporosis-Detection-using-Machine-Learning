# %% [markdown]
# # Osteoporosis Classification using Deep Learning

# %% [markdown]
# ## Architectures Printing

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/VGG16_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, 
           to_file="VGG16.png", 
           show_shapes=True, 
           show_layer_names=True, 
           dpi=100,  # Increase resolution
           rankdir="TB")  # 'TB' = Top to Bottom layout

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/VGG19_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, to_file="VGG19.jpg", show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/InceptionV3_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, to_file="InceptionV3.pdf", show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
#
# InvocationException                       Traceback (most recent call last)
#
# <ipython-input-8-e576edbe1851> in <cell line: 8>()
#
#       6
#
#       7 # Plot the model architecture
#
# ----> 8 plot_model(model, to_file="InceptionV3.pdf", show_shapes=True, show_layer_names=True)
#
#
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/model_visualization.py in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#
#     467         extension = extension[1:]
#
#     468     # Save image to disk.
#
# --> 469     dot.write(to_file, format=extension)
#
#     470     # Return the image as a Jupyter Image object, to be displayed in-line.
#
#     471     # Note that we cannot easily detect whether the code is running in a
#
#
#
# ...

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/ResNet50_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, to_file="ResNet50.jpg", show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
#
# InvocationException                       Traceback (most recent call last)
#
# <ipython-input-9-bf0e1f2f2bc3> in <cell line: 8>()
#
#       6
#
#       7 # Plot the model architecture
#
# ----> 8 plot_model(model, to_file="ResNet50.jpg", show_shapes=True, show_layer_names=True)
#
#
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/model_visualization.py in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#
#     467         extension = extension[1:]
#
#     468     # Save image to disk.
#
# --> 469     dot.write(to_file, format=extension)
#
#     470     # Return the image as a Jupyter Image object, to be displayed in-line.
#
#     471     # Note that we cannot easily detect whether the code is running in a
#
#
#
# ...

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/AlexNet_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, to_file="AlexNet.jpg", show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/Xception_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, to_file="Xception.jpg", show_shapes=True, show_layer_names=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.769377 to fit

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model("/kaggle/input/osteoporosis-models/keras/default/1/CustomCNN_3_knee_osteo_model.keras")

# Plot the model architecture
plot_model(model, to_file="CustomCNN.jpg", show_shapes=True, show_layer_names=True)
